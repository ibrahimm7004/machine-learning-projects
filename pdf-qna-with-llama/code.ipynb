# %%
import PyPDF2
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers

# %%
file_path = r'EQUITY Factsheet_ Adobe Inc. (1).pdf'

# %%
def read_document(file_path):
    with open(file_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ''
        for page_num in range(len(reader.pages)):
            page = reader.pages[page_num]
            text += page.extract_text()
    return text

# %%
document_content = read_document(file_path)

# %%
def get_llama_response(prompt, temperature=0.7):
    llm = CTransformers(model=r"C:\Users\hp\Desktop\sem6\PL Lab\lab10\llama-2-13b.ggmlv3.q2_K.bin",
                        model_type="llama",
                        config={"max_new_tokens": 256, "temperature": temperature})
    response = llm(prompt)
    return response

# %%
while True:
    user_input = input("Your question: ")
    
    if user_input.lower() in ['q', 'quit']:
        print("Exiting")
        break
    
    max_tokens = 512  
    chunks = [document_content[i:i + max_tokens] for i in range(0, len(document_content), max_tokens)]
    
    for chunk in chunks:
        response = get_llama_response(chunk)
        print(response)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
#  of a potential investment in Adobe Inc. or any other entity. This report has been prepared by CFRA (an independently owned research firm) and does not reflect the opinions or views of Adobe Inc. or any of its affiliates, subsidiaries or parent company.
# Adobe Inc.
# 4.25  -0.25 (-5%)  1,837,896    |   $102.21      |
# 14:00AM | 09/13 0.0% 0.0%  99.46
# Aug 26  1,837,896  09/09  1,837,895
# Aug 26  1,837,896  09/09  1,837,896
# Aug 26  1,837,896  09/09  1,837,895
# Aug 26  1,837,896  09/09  1,837,89
#  taxes from their personal tax advisers.
# ...
